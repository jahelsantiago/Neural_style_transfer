# %%
import os
import sys
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image
import matplotlib.image as mpimg

# %%
from Style_Transfer import *
# Out:
# C:\Users\ProBook\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ProBook\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ProBook\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ### Seleccionamos la content image

# %%
content_image = mpimg.imread("content_images/unal.jpg")
plt.imshow(content_image)

# %% [markdown]
# ### Seleccionamos la style image

# %%
style_image = mpimg.imread("style_images/Starry-Night.jpg")
plt.imshow(style_image)

# %%
transfer_style(content_image, style_image, save_preimage = True, num_iterations= 200)
# Out:
# WARNING:tensorflow:From C:\Users\ProBook\Desktop\Conocimiento\Neural_Style_Transfer\Style_Transfer.py:131: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\ProBook\Desktop\Conocimiento\Neural_Style_Transfer\Style_Transfer.py:132: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From C:\Users\ProBook\Desktop\Conocimiento\Neural_Style_Transfer\utils.py:124: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\ProBook\Desktop\Conocimiento\Neural_Style_Transfer\Style_Transfer.py:156: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# ...
